# %%
# Importing Libraries : 
import pandas as pd
import random
import spacy
from spacy.training import Example
from spacy.pipeline.ner import DEFAULT_NER_MODEL
import re
from time import sleep
import re
from spacy import logger
from spacy import displacy

import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix, classification_report

# %%
# Loading the dataset : 
training_file = 'training.txt'
testing_file  = 'test.txt'

with open("training.txt", "r") as train_file:
    training_data = train_file.read()

with open("test.txt", "r") as test_file:
    testing_data = test_file.read()

# Training set : bifuricating the text based on the title and annotations
ctr = 0
train = []
for line in training_data.split("\n\n"):
  train.append(line)

# Test Set:
ctr = 0
test = []
for line in testing_data.split("\n\n"):
  test.append(line)

# %%
# Extracting the Titles and Makig the annotations : 
try:

  def article_extractor(text):
    article = re.findall(r'a\|(.*)\n' , text)
    return article[0]

  def title_extractor(text):
    title = re.findall(r't\|(.*)\n' , text)
    return title[0]

except Exception as e:
  pass

train_article  = []
try:
  for x in train:
    train_article.append(title_extractor(x)+' '+article_extractor(x))
except Exception as e:
  pass

test_article  = []
try:
  for x in test:
    test_article.append(title_extractor(x)+' '+article_extractor(x))
except Exception as e:
  pass

# %%
# Selecting the labels from the dataset :

try:
  def get_labels(text):
    l  = re.findall(r'\t(.*)' , text)
    l = [x.split('\t') for x in l]
    labels  = []
    for i in l:
      try:
        labels.append((int(i[0]) , int(i[1]) , i[3]))
      except Exception as e:
        pass
    return labels


  def get_labels_and_entity(text):
    l = re.findall(r'\t(.*)' , text)
    l = [x.split('\t') for x in l]
    labels  = []
    for i in l:
      try:
        labels.append((int(i[0]) , int(i[1]) , i[3], i[2]))
      except Exception as e:
        pass
    return labels
except Exception as e:
  pass

train_labels  = [get_labels(x) for x in train]
test_labels = [get_labels(x) for x in test]

train_labels = [{"entities": entry} for entry in train_labels]
test_labels = [{"entities": entry} for entry in test_labels] 

# The entities text is added in the dataset as training spacy model needs to have a specifi format :

# %%
# Making the data frame : 

train_df  = pd.DataFrame(train_article, columns=['article'])
test_df  = pd.DataFrame(test_article, columns=['article'])

min_length = min(len(test_df), len(test_labels), len(train_df), len(train_labels))

test_df = test_df.iloc[:min_length].copy()
train_df = train_df.iloc[:min_length].copy()

test_df['labels'] = test_labels[:min_length]
train_df['labels'] = train_labels[:min_length]

# %%
train_data  = []
test_data = []

for _, row in train_df.iterrows():
    text = row['article']
    entities = row['labels']['entities'] 
    train_data.append((text, {"entities": entities}))

# print(train_data[0])

for _, row in test_df.iterrows():
    text = row['article']
    entities = row['labels']['entities']
    
    test_data.append((text, {"entities": entities}))

# %%
test_data[0]
# Out:
# ('Famotidine-associated delirium. A series of six cases. Famotidine is a histamine H2-receptor antagonist used in inpatient settings for prevention of stress ulcers and is showing increasing popularity because of its low cost. Although all of the currently available H2-receptor antagonists have shown the propensity to cause delirium, only two previously reported cases have been associated with famotidine. The authors report on six cases of famotidine-associated delirium in hospitalized patients who cleared completely upon removal of famotidine. The pharmacokinetics of famotidine are reviewed, with no change in its metabolism in the elderly population seen. The implications of using famotidine in elderly persons are discussed.',
#  {'entities': [(0, 10, 'Chemical'),
#    (22, 30, 'Disease'),
#    (55, 65, 'Chemical'),
#    (156, 162, 'Disease'),
#    (324, 332, 'Disease'),
#    (395, 405, 'Chemical'),
#    (442, 452, 'Chemical'),
#    (464, 472, 'Disease'),
#    (537, 547, 'Chemical'),
#    (573, 583, 'Chemical'),
#    (689, 699, 'Chemical')]})

# %%
train_data[0]
# Out:
# ('Naloxone reverses the antihypertensive effect of clonidine. In unanesthetized, spontaneously hypertensive rats the decrease in blood pressure and heart rate produced by intravenous clonidine, 5 to 20 micrograms/kg, was inhibited or reversed by nalozone, 0.2 to 2 mg/kg. The hypotensive effect of 100 mg/kg alpha-methyldopa was also partially reversed by naloxone. Naloxone alone did not affect either blood pressure or heart rate. In brain membranes from spontaneously hypertensive rats clonidine, 10(-8) to 10(-5) M, did not influence stereoselective binding of [3H]-naloxone (8 nM), and naloxone, 10(-8) to 10(-4) M, did not influence clonidine-suppressible binding of [3H]-dihydroergocryptine (1 nM). These findings indicate that in spontaneously hypertensive rats the effects of central alpha-adrenoceptor stimulation involve activation of opiate receptors. As naloxone and clonidine do not appear to interact with the same receptor site, the observed functional antagonism suggests the release of an endogenous opiate by clonidine or alpha-methyldopa and the possible role of the opiate in the central control of sympathetic tone.',
#  {'entities': [(0, 8, 'Chemical'),
#    (49, 58, 'Chemical'),
#    (93, 105, 'Disease'),
#    (181, 190, 'Chemical'),
#    (244, 252, 'Chemical'),
#    (274, 285, 'Disease'),
#    (306, 322, 'Chemical'),
#    (354, 362, 'Chemical'),
#    (364, 372, 'Chemical'),
#    (469, 481, 'Disease'),
#    (487, 496, 'Chemical'),
#    (563, 576, 'Chemical'),
#    (589, 597, 'Chemical'),
#    (637, 646, 'Chemical'),
#    (671, 695, 'Chemical'),
#    (750, 762, 'Disease'),
#    (865, 873, 'Chemical'),
#    (878, 887, 'Chemical'),
#    (1026, 1035, 'Chemical'),
#    (1039, 1055, 'Chemical')]})

# %%
### Both the train and test dataset are done and now we can train the model : 
nlp = spacy.blank("en")
ner = nlp.add_pipe("ner")

nlp.initialize()

def train_ner(nlp, train_data, iterations=10):
    optimizer = nlp.create_optimizer()
    for epoch in range(iterations):
        random.shuffle(train_data)
        losses = {}
        for text, annotations in train_data:
            example = Example.from_dict(nlp.make_doc(text), annotations)
            nlp.update([example], drop=0.4, losses=losses)
        print(f"Epoch {epoch+1}, Loss: {losses}")

# %%
# Call the train ner function : for training the model :
train_ner(nlp, train_data)
# Out:
# c:\Users\vinay\AppData\Local\Programs\Python\Python310\lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Epithelial sodium channel (ENaC) subunit mRNA and ..." with entities "[(11, 17, 'Chemical'), (82, 107, 'Chemical'), (116...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# c:\Users\vinay\AppData\Local\Programs\Python\Python310\lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Conformationally restricted analogs of BD1008 and ..." with entities "[(39, 45, 'Chemical'), (63, 83, 'Chemical'), (124,...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# c:\Users\vinay\AppData\Local\Programs\Python\Python310\lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Brain natriuretic peptide is a predictor of anthra..." with entities "[(44, 57, 'Chemical'), (66, 80, 'Disease'), (82, 9...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# c:\Users\vinay\AppData\Local\Programs\Python\Python310\lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Pentoxifylline (Trental) does not inhibit dipyrida..." with entities "[(0, 14, 'Chemical'), (16, 23, 'Chemical'), (42, 5...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# c:\Users\vinay\AppData\Local\Programs\Python\Python310\lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Hemolysis of human erythrocytes induced by tamoxif..." with entities "[(0, 9, 'Disease'), (43, 52, 'Chemical'), (101, 11...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# c:\Users\vinay\AppData\Local\Programs\Python\Python310\lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Valproic acid induced encephalopathy--19 new cases..." with entities "[(0, 13, 'Chemical'), (22, 36, 'Disease'), (109, 1...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# c:\Users\vinay\AppData\Local\Programs\Python\Python310\lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Ketoconazole induced torsades de pointes without c..." with entities "[(0, 12, 'Chemical'), (21, 40, 'Disease'), (97, 10...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# c:\Users\vinay\AppData\Local\Programs\Python\Python310\lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Changes of sodium and ATP affinities of the cardia..." with entities "[(11, 17, 'Chemical'), (22, 25, 'Chemical'), (53, ...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# c:\Users\vinay\AppData\Local\Programs\Python\Python310\lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Study of the role of vitamin B12 and folinic acid ..." with entities "[(21, 32, 'Chemical'), (37, 49, 'Chemical'), (92, ...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# c:\Users\vinay\AppData\Local\Programs\Python\Python310\lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Time course of lipid peroxidation in puromycin ami..." with entities "[(37, 62, 'Chemical'), (71, 82, 'Disease'), (93, 9...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# c:\Users\vinay\AppData\Local\Programs\Python\Python310\lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "In vivo protection of dna damage associated apopto..." with entities "[(58, 66, 'Disease'), (86, 99, 'Chemical'), (108, ...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# c:\Users\vinay\AppData\Local\Programs\Python\Python310\lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Effect of green tea and vitamin E combination in i..." with entities "[(10, 19, 'Chemical'), (24, 33, 'Chemical'), (49, ...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# c:\Users\vinay\AppData\Local\Programs\Python\Python310\lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Combined effects of prolonged prostaglandin E1-ind..." with entities "[(30, 46, 'Chemical'), (55, 66, 'Disease'), (71, 8...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# c:\Users\vinay\AppData\Local\Programs\Python\Python310\lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Elevation of ADAM10, ADAM17, MMP-2 and MMP-9 expre..." with entities "[(89, 94, 'Chemical'), (103, 127, 'Disease'), (205...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# c:\Users\vinay\AppData\Local\Programs\Python\Python310\lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Mechanisms of FK 506-induced hypertension in the r..." with entities "[(14, 20, 'Chemical'), (29, 41, 'Disease'), (55, 6...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# c:\Users\vinay\AppData\Local\Programs\Python\Python310\lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Cerebral blood flow and metabolism during isoflura..." with entities "[(42, 52, 'Chemical'), (61, 72, 'Disease'), (110, ...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# c:\Users\vinay\AppData\Local\Programs\Python\Python310\lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Crossover comparison of efficacy and preference fo..." with entities "[(52, 63, 'Chemical'), (77, 87, 'Chemical'), (88, ...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# c:\Users\vinay\AppData\Local\Programs\Python\Python310\lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Two mouse lines selected for differential sensitiv..." with entities "[(59, 73, 'Chemical'), (82, 90, 'Disease'), (169, ...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# c:\Users\vinay\AppData\Local\Programs\Python\Python310\lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "The hematologic effects of cefonicid and cefazedon..." with entities "[(27, 36, 'Chemical'), (41, 51, 'Chemical'), (85, ...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# c:\Users\vinay\AppData\Local\Programs\Python\Python310\lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "The selective 5-HT6 receptor antagonist Ro4368554 ..." with entities "[(40, 49, 'Chemical'), (120, 137, 'Disease'), (165...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# c:\Users\vinay\AppData\Local\Programs\Python\Python310\lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Curcumin ameliorates cognitive dysfunction and oxi..." with entities "[(0, 8, 'Chemical'), (21, 42, 'Disease'), (67, 81,...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# c:\Users\vinay\AppData\Local\Programs\Python\Python310\lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Reversible dilated cardiomyopathy related to ampho..." with entities "[(11, 33, 'Disease'), (45, 59, 'Chemical'), (105, ...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# c:\Users\vinay\AppData\Local\Programs\Python\Python310\lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Protective efficacy of neuroactive steroids agains..." with entities "[(35, 43, 'Chemical'), (52, 59, 'Chemical'), (68, ...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# c:\Users\vinay\AppData\Local\Programs\Python\Python310\lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Organophosphate-induced convulsions and prevention..." with entities "[(0, 15, 'Chemical'), (24, 35, 'Disease'), (54, 79...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# c:\Users\vinay\AppData\Local\Programs\Python\Python310\lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Pharmacological evidence for the potential of Dauc..." with entities "[(81, 103, 'Disease'), (221, 232, 'Chemical'), (29...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# c:\Users\vinay\AppData\Local\Programs\Python\Python310\lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Interactive effects of variations in [Na]o and [Ca..." with entities "[(38, 40, 'Chemical'), (48, 50, 'Chemical'), (149,...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# c:\Users\vinay\AppData\Local\Programs\Python\Python310\lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Development of ocular myasthenia during pegylated ..." with entities "[(15, 32, 'Disease'), (40, 60, 'Chemical'), (65, 7...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# c:\Users\vinay\AppData\Local\Programs\Python\Python310\lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Evaluation of cardiac troponin I and T levels as m..." with entities "[(60, 77, 'Disease'), (81, 92, 'Chemical'), (101, ...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# c:\Users\vinay\AppData\Local\Programs\Python\Python310\lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Seizures induced by the cocaine metabolite benzoyl..." with entities "[(0, 8, 'Disease'), (24, 31, 'Chemical'), (43, 58,...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# c:\Users\vinay\AppData\Local\Programs\Python\Python310\lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Antinociceptive and antiamnesic properties of the ..." with entities "[(84, 88, 'Chemical'), (120, 162, 'Chemical'), (17...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# c:\Users\vinay\AppData\Local\Programs\Python\Python310\lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Antagonism between interleukin 3 and erythropoieti..." with entities "[(65, 79, 'Chemical'), (88, 94, 'Disease'), (133, ...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# c:\Users\vinay\AppData\Local\Programs\Python\Python310\lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Adriamycin-induced autophagic cardiomyocyte death ..." with entities "[(0, 10, 'Chemical'), (44, 49, 'Disease'), (92, 10...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# c:\Users\vinay\AppData\Local\Programs\Python\Python310\lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Rebound hypertensive after sodium nitroprusside pr..." with entities "[(8, 20, 'Disease'), (27, 47, 'Chemical'), (61, 70...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# c:\Users\vinay\AppData\Local\Programs\Python\Python310\lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Mutations associated with lamivudine-resistance in..." with entities "[(26, 36, 'Chemical'), (59, 61, 'Chemical'), (66, ...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# c:\Users\vinay\AppData\Local\Programs\Python\Python310\lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Warfarin-induced artery calcification is accelerat..." with entities "[(0, 8, 'Chemical'), (17, 37, 'Disease'), (67, 76,...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# c:\Users\vinay\AppData\Local\Programs\Python\Python310\lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Acute reserpine and subchronic haloperidol treatme..." with entities "[(6, 15, 'Chemical'), (31, 42, 'Chemical'), (80, 8...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# c:\Users\vinay\AppData\Local\Programs\Python\Python310\lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Recurrent excitation in the dentate gyrus of a mur..." with entities "[(63, 85, 'Disease'), (113, 124, 'Chemical'), (142...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# c:\Users\vinay\AppData\Local\Programs\Python\Python310\lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "A selective dopamine D4 receptor antagonist, NRA01..." with entities "[(12, 20, 'Chemical'), (45, 52, 'Chemical'), (98, ...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# c:\Users\vinay\AppData\Local\Programs\Python\Python310\lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Protection against amphetamine-induced neurotoxici..." with entities "[(19, 30, 'Chemical'), (39, 52, 'Disease'), (69, 7...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# c:\Users\vinay\AppData\Local\Programs\Python\Python310\lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Anti-oxidant effects of atorvastatin in dexamethas..." with entities "[(24, 36, 'Chemical'), (40, 53, 'Chemical'), (62, ...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# c:\Users\vinay\AppData\Local\Programs\Python\Python310\lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Calcineurin-inhibitor induced pain syndrome (CIPS)..." with entities "[(30, 34, 'Disease'), (45, 49, 'Disease'), (118, 1...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# c:\Users\vinay\AppData\Local\Programs\Python\Python310\lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Upregulation of the expression of vasopressin gene..." with entities "[(34, 45, 'Chemical'), (103, 110, 'Chemical'), (11...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# c:\Users\vinay\AppData\Local\Programs\Python\Python310\lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Prenatal protein deprivation alters dopamine-media..." with entities "[(36, 44, 'Chemical'), (215, 228, 'Disease'), (390...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# c:\Users\vinay\AppData\Local\Programs\Python\Python310\lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Spironolactone-induced renal insufficiency and hyp..." with entities "[(0, 14, 'Chemical'), (23, 42, 'Disease'), (47, 59...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# c:\Users\vinay\AppData\Local\Programs\Python\Python310\lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Encephalopathy induced by levetiracetam added to v..." with entities "[(0, 14, 'Disease'), (26, 39, 'Chemical'), (49, 58...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# c:\Users\vinay\AppData\Local\Programs\Python\Python310\lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "A novel compound, maltolyl p-coumarate, attenuates..." with entities "[(18, 38, 'Chemical'), (51, 69, 'Disease'), (125, ...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# Epoch 1, Loss: {'ner': np.float32(14481.574)}
# Epoch 2, Loss: {'ner': np.float32(8381.821)}
# Epoch 3, Loss: {'ner': np.float32(6577.9463)}
# Epoch 4, Loss: {'ner': np.float32(5298.951)}
# Epoch 5, Loss: {'ner': np.float32(4530.48)}
# Epoch 6, Loss: {'ner': np.float32(3951.384)}
# Epoch 7, Loss: {'ner': np.float32(3555.3608)}
# Epoch 8, Loss: {'ner': np.float32(3184.35)}
# Epoch 9, Loss: {'ner': np.float32(3097.5032)}
# Epoch 10, Loss: {'ner': np.float32(2675.3225)}

# %%
# Make function for the uncertain predictions and feed some unlabeled data in the model : 

def get_uncertain_predictions(nlp, texts, threshold=0.5):
    uncertain_samples = []
    for text in texts:
        doc = nlp(text)
        for ent in doc.ents:
            # Simulate uncertainty based on entity length (longer names -> more confidence)
            confidence = len(ent.text) / len(text)
            if confidence < threshold:
                uncertain_samples.append((text, ent.text, ent.label_, confidence))
    return uncertain_samples

UNLABELED_DATA = [
    "Ibuprofen is a pain reliever.",
    "Clonidine is used for blood pressure control.",
    "Patients with diabetes should monitor sugar levels.",
]

uncertain_samples = get_uncertain_predictions(nlp, UNLABELED_DATA)

# %%
test_data[0][0]
# Out:
# 'Famotidine-associated delirium. A series of six cases. Famotidine is a histamine H2-receptor antagonist used in inpatient settings for prevention of stress ulcers and is showing increasing popularity because of its low cost. Although all of the currently available H2-receptor antagonists have shown the propensity to cause delirium, only two previously reported cases have been associated with famotidine. The authors report on six cases of famotidine-associated delirium in hospitalized patients who cleared completely upon removal of famotidine. The pharmacokinetics of famotidine are reviewed, with no change in its metabolism in the elderly population seen. The implications of using famotidine in elderly persons are discussed.'

# %%
# Model Testing : setting the data using displacy :: 
colors  = {
    "Disease" : "#ff698f",
    "Chemical" : "#1472ff"
}

options  = {"ents" : ["Disease" , "Chemical"] , "colors" : colors}

# %%
def save_model(nlp, model_path):
    nlp.to_disk(model_path)
    print(f"Model saved to {model_path}")

save_model(nlp=nlp , model_path="saved_model")
# Out:
# Model saved to saved_model

# %%
# Check the model for some random text :: from testing data ::
# Lets check the test for the first 10 entries and see the output : 

nlp = spacy.load('saved_model')

for i in range(5):
    text = test_data[i][0]
    doc  = nlp(text=text)
    spacy.displacy.render(doc ,style  = "ent" , jupyter = True  , options = options)
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: #1472ff; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Famotidine
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">Chemical</span>
# </mark>
# -associated
# <mark class="entity" style="background: #ff698f; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     delirium
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">Disease</span>
# </mark>
# . A series of six cases.
# <mark class="entity" style="background: #1472ff; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Famotidine
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">Chemical</span>
# </mark>
#  is a
# <mark class="entity" style="background: #1472ff; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     histamine
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">Chemical</span>
# </mark>
#  H2-receptor antagonist used in inpatient settings for prevention of stress ulcers and is showing increasing popularity because of its low cost. Although all of the currently available H2-receptor antagonists have shown the propensity to cause
# <mark class="entity" style="background: #ff698f; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     delirium
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">Disease</span>
# </mark>
# , only two previously reported cases have been associated with
# <mark class="entity" style="background: #1472ff; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     famotidine
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">Chemical</span>
# </mark>
# . The authors report on six cases of
# <mark class="entity" style="background: #1472ff; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     famotidine
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">Chemical</span>
# </mark>
# -associated
# <mark class="entity" style="background: #ff698f; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     delirium
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">Disease</span>
# </mark>
#  in hospitalized patients who cleared completely upon removal of
# <mark class="entity" style="background: #1472ff; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     famotidine
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">Chemical</span>
# </mark>
# . The pharmacokinetics of
# <mark class="entity" style="background: #1472ff; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     famotidine
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">Chemical</span>
# </mark>
#  are reviewed, with no change in its metabolism in the elderly population seen. The implications of using
# <mark class="entity" style="background: #1472ff; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     famotidine
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">Chemical</span>
# </mark>
#  in elderly persons are discussed.</div></span>
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: #1472ff; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Indomethacin
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">Chemical</span>
# </mark>
#  induced
# <mark class="entity" style="background: #ff698f; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     hypotension
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">Disease</span>
# </mark>
#  in
# <mark class="entity" style="background: #1472ff; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     sodium
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">Chemical</span>
# </mark>
#  and volume depleted rats. After a single oral dose of 4 mg/kg
# <mark class="entity" style="background: #1472ff; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     indomethacin
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">Chemical</span>
# </mark>
#  (IDM) to
# <mark class="entity" style="background: #1472ff; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     sodium
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">Chemical</span>
# </mark>
#  and volume depleted rats plasma renin activity (PRA) and systolic blood pressure fell significantly within four hours. In
# <mark class="entity" style="background: #1472ff; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     sodium
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">Chemical</span>
# </mark>
#  repleted animals
# <mark class="entity" style="background: #1472ff; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     indomethacin
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">Chemical</span>
# </mark>
#  did not change systolic blood pressure (BP) although plasma renin activity was decreased. Thus,
# <mark class="entity" style="background: #1472ff; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     indomethacin
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">Chemical</span>
# </mark>
#  by inhibition of
# <mark class="entity" style="background: #1472ff; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     prostaglandin
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">Chemical</span>
# </mark>
#  synthesis may diminish the blood pressure maintaining effect of the stimulated renin-
# <mark class="entity" style="background: #1472ff; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     angiotensin
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">Chemical</span>
# </mark>
#  system in
# <mark class="entity" style="background: #1472ff; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     sodium
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">Chemical</span>
# </mark>
#  and volume depletion.</div></span>
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">Late-onset
# <mark class="entity" style="background: #1472ff; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     scleroderma
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">Chemical</span>
# </mark>
#  renal crisis induced by
# <mark class="entity" style="background: #1472ff; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     tacrolimus
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">Chemical</span>
# </mark>
#  and
# <mark class="entity" style="background: #1472ff; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     prednisolone
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">Chemical</span>
# </mark>
# : a case report.
# <mark class="entity" style="background: #ff698f; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Scleroderma renal crisis
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">Disease</span>
# </mark>
#  (
# <mark class="entity" style="background: #ff698f; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     SRC
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">Disease</span>
# </mark>
# ) is a rare complication of
# <mark class="entity" style="background: #ff698f; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     systemic sclerosis
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">Disease</span>
# </mark>
#  (SSc) but can be severe enough to require temporary or permanent renal replacement therapy. Moderate to high dose corticosteroid use is recognized as a major risk factor for
# <mark class="entity" style="background: #ff698f; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     SRC
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">Disease</span>
# </mark>
# . Furthermore, there have been reports of
# <mark class="entity" style="background: #ff698f; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     thrombotic microangiopathy
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">Disease</span>
# </mark>
#  precipitated by
# <mark class="entity" style="background: #1472ff; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     cyclosporine
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">Chemical</span>
# </mark>
#  in patients with SSc. In this article, we report a patient with
# <mark class="entity" style="background: #ff698f; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     SRC
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">Disease</span>
# </mark>
#  induced by
# <mark class="entity" style="background: #1472ff; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     tacrolimus
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">Chemical</span>
# </mark>
#  and
# <mark class="entity" style="background: #1472ff; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     corticosteroids
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">Chemical</span>
# </mark>
# . The aim of this work is to call attention to the risk of
# <mark class="entity" style="background: #1472ff; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     tacrolimus
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">Chemical</span>
# </mark>
#  use in patients with SSc.</div></span>
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">The risk and associated factors of
# <mark class="entity" style="background: #1472ff; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     methamphetamine
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">Chemical</span>
# </mark>
#
# <mark class="entity" style="background: #ff698f; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     psychosis
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">Disease</span>
# </mark>
#  in
# <mark class="entity" style="background: #1472ff; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     methamphetamine
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">Chemical</span>
# </mark>
# -dependent patients in Malaysia. OBJECTIVE: The objective of this study was to determine the risk of lifetime and current
# <mark class="entity" style="background: #1472ff; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     methamphetamine
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">Chemical</span>
# </mark>
# -induced
# <mark class="entity" style="background: #ff698f; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     psychosis
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">Disease</span>
# </mark>
#  in patients with
# <mark class="entity" style="background: #1472ff; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     methamphetamine
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">Chemical</span>
# </mark>
#
# <mark class="entity" style="background: #ff698f; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     dependence
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">Disease</span>
# </mark>
# . The association between
# <mark class="entity" style="background: #ff698f; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     psychiatric
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">Disease</span>
# </mark>
#  co-morbidity and
# <mark class="entity" style="background: #1472ff; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     methamphetamine
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">Chemical</span>
# </mark>
# -induced
# <mark class="entity" style="background: #ff698f; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     psychosis
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">Disease</span>
# </mark>
#  was also studied. METHODS: This was a cross-sectional study conducted concurrently at a teaching hospital and a drug rehabilitation center in Malaysia. Patients with the diagnosis of
# <mark class="entity" style="background: #1472ff; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     methamphetamine
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">Chemical</span>
# </mark>
#  based on DSM-IV were interviewed using the Mini International Neuropsychiatric Interview (M.I.N.I.) for
# <mark class="entity" style="background: #1472ff; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     methamphetamine
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">Chemical</span>
# </mark>
# -induced
# <mark class="entity" style="background: #ff698f; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     psychosis
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">Disease</span>
# </mark>
#  and other Axis I
# <mark class="entity" style="background: #ff698f; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     psychiatric disorders
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">Disease</span>
# </mark>
# . The information on sociodemographic background and drug use history was obtained from interview or medical records. RESULTS: Of 292 subjects, 47.9% of the subjects had a past history of
# <mark class="entity" style="background: #ff698f; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     psychotic symptoms
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">Disease</span>
# </mark>
#  and 13.0% of the patients were having current
# <mark class="entity" style="background: #ff698f; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     psychotic symptoms
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">Disease</span>
# </mark>
# . Co-morbid major
# <mark class="entity" style="background: #ff698f; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     depressive disorder
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">Disease</span>
# </mark>
#  (OR=7.18, 95 CI=2.612-19.708),
# <mark class="entity" style="background: #ff698f; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     bipolar disorder
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">Disease</span>
# </mark>
#  (
# <mark class="entity" style="background: #ff698f; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     OR=13.807
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">Disease</span>
# </mark>
# , 95 CI=5.194-36.706),
# <mark class="entity" style="background: #ff698f; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     antisocial personality disorder
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">Disease</span>
# </mark>
#  (OR=12.619, 95 CI=6.702-23.759) and heavy
# <mark class="entity" style="background: #1472ff; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     methamphetamine
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">Chemical</span>
# </mark>
#  uses were significantly associated with lifetime
# <mark class="entity" style="background: #1472ff; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     methamphetamine
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">Chemical</span>
# </mark>
# -induced
# <mark class="entity" style="background: #ff698f
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">Cerebellar sensory processing alterations impact motor cortical plasticity in
# <mark class="entity" style="background: #ff698f; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Parkinson's disease
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">Disease</span>
# </mark>
# : clues from dyskinetic patients. The plasticity of primary motor cortex (M1) in patients with
# <mark class="entity" style="background: #ff698f; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Parkinson's disease
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">Disease</span>
# </mark>
#  (
# <mark class="entity" style="background: #ff698f; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     PD
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">Disease</span>
# </mark>
# ) and
# <mark class="entity" style="background: #1472ff; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     levodopa
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">Chemical</span>
# </mark>
# -induced
# <mark class="entity" style="background: #ff698f; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     dyskinesias
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">Disease</span>
# </mark>
#  (
# <mark class="entity" style="background: #ff698f; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     LIDs
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">Disease</span>
# </mark>
# ) is severely impaired. We recently reported in young healthy subjects that inhibitory cerebellar stimulation enhanced the sensorimotor plasticity of M1 that was induced by paired associative stimulation (
# <mark class="entity" style="background: #1472ff; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     PAS
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">Chemical</span>
# </mark>
# ). This study demonstrates that the deficient sensorimotor M1 plasticity in 16 patients with
# <mark class="entity" style="background: #ff698f; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     LIDs
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">Disease</span>
# </mark>
#  could be reinstated by a single session of real inhibitory cerebellar stimulation but not sham stimulation. This was evident only when a sensory component was involved in the induction of plasticity, indicating that cerebellar sensory processing function is involved in the resurgence of M1 plasticity. The benefit of inhibitory cerebellar stimulation on
# <mark class="entity" style="background: #ff698f; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     LIDs
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">Disease</span>
# </mark>
#  is known. To explore whether this benefit is linked to the restoration of sensorimotor plasticity of M1, we conducted an additional study looking at changes in
# <mark class="entity" style="background: #ff698f; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     LIDs
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">Disease</span>
# </mark>
#  and
# <mark class="entity" style="background: #1472ff; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     PAS
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">Chemical</span>
# </mark>
# -induced plasticity after 10 sessions of either bilateral, real inhibitory cerebellar stimulation or sham stimulation. Only real and not sham stimulation had an antidyskinetic effect and it was paralleled by a resurgence in the sensorimotor plasticity of M1. These results suggest that alterations in cerebellar sensory processing function, occurring secondary to
# <mark class="entity" style="background: #ff698f; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     abnormal basal ganglia signals
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">Disease</span>
# </mark>
#  reaching it, may be an important element contributing to the maladaptive sensorimotor plasticity of M1 and the emergence of
# <mark class="entity" style="background: #ff698f; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     abnormal involuntary movements
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">Disease</span>
# </mark>
# .</div></span>

# %%
model_path =   'saved_model'
check_model  = spacy.load(model_path)

sample_text = input("Enter Medical Based Text  :")

doc = check_model(sample_text)
spacy.displacy.render(doc ,style  = "ent" , jupyter = True , options = options )
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">I am geeling
# <mark class="entity" style="background: #ff698f; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Headache
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">Disease</span>
# </mark>
#  and Dont feel good
# <mark class="entity" style="background: #1472ff; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     aspirin
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">Chemical</span>
# </mark>
# </div></span>
